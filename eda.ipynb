# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 10)
np.set_printoptions(precision = 3)
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %%
### Reading and merging the EyeT dataset into a dictionary of dataframes 

par2_t0 = pd.read_csv(r"C:\Users\sm22181\Desktop\EyeT\EyeT_group_dataset_II_image_name_grey_blue_participant_2_trial_0.csv", index_col = 'Unnamed: 0')
par12_t0 = pd.read_csv(r"C:\Users\sm22181\Desktop\EyeT\EyeT_group_dataset_II_image_name_grey_orange_participant_12_trial_0.csv", index_col = 'Unnamed: 0')
par1_t0 = pd.read_csv(r"C:\Users\sm22181\Desktop\EyeT\EyeT_group_dataset_III_image_name_letter_card_participant_1_trial_0.csv", index_col = 'Unnamed: 0')

# %%
par2_t0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7268 entries, 6103 to 13370
# Data columns (total 70 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Recording timestamp                  7268 non-null   int64
#  1   Computer timestamp                   7268 non-null   int64
#  2   Sensor                               7257 non-null   object
#  3   Project name                         7268 non-null   object
#  4   Export date                          7268 non-null   object
#  5   Participant name                     7268 non-null   object
#  6   Recording name                       7268 non-null   object
#  7   Recording date                       7268 non-null   object
#  8   Recording date UTC                   7268 non-null   object
#  9   Recording start time                 7268 non-null   object
#  10  Recording start time UTC             7268 non-null   object
#  11  Recording duration                   7268 non-null   int64
#  12  Timeline name                        7268 non-null   object
#  13  Recording Fixation filter name       7268 non-null   object
#  14  Recording software version           7268 non-null   object
#  15  Recording resolution height          7268 non-null   int64
#  16  Recording resolution width           7268 non-null   int64
#  17  Recording monitor latency            7268 non-null   object
#  18  Eyetracker timestamp                 6909 non-null   float64
#  19  Event                                11 non-null     object
#  20  Event value                          10 non-null     object
#  21  Gaze point X                         6448 non-null   float64
#  22  Gaze point Y                         6448 non-null   float64
#  23  Gaze point left X                    6158 non-null   float64
#  24  Gaze point left Y                    6158 non-null   float64
#  25  Gaze point right X                   5932 non-null   float64
#  26  Gaze point right Y                   5932 non-null   float64
#  27  Gaze direction left X                6158 non-null   object
#  28  Gaze direction left Y                6158 non-null   object
#  29  Gaze direction left Z                6158 non-null   object
#  30  Gaze direction right X               5932 non-null   object
#  31  Gaze direction right Y               5932 non-null   object
#  32  Gaze direction right Z               5932 non-null   object
#  33  Pupil diameter left                  1916 non-null   object
#  34  Pupil diameter right                 1760 non-null   object
#  35  Validity left                        6909 non-null   object
#  36  Validity right                       6909 non-null   object
#  37  Eye position left X (DACSmm)         6158 non-null   object
#  38  Eye position left Y (DACSmm)         6158 non-null   object
#  39  Eye position left Z (DACSmm)         6158 non-null   object
#  40  Eye position right X (DACSmm)        5932 non-null   object
#  41  Eye position right Y (DACSmm)        5932 non-null   object
#  42  Eye position right Z (DACSmm)        5932 non-null   object
#  43  Gaze point left X (DACSmm)           6158 non-null   object
#  44  Gaze point left Y (DACSmm)           6158 non-null   object
#  45  Gaze point right X (DACSmm)          5932 non-null   object
#  46  Gaze point right Y (DACSmm)          5932 non-null   object
#  47  Gaze point X (MCSnorm)               6139 non-null   object
#  48  Gaze point Y (MCSnorm)               6139 non-null   object
#  49  Gaze point left X (MCSnorm)          5958 non-null   object
#  50  Gaze point left Y (MCSnorm)          5958 non-null   object
#  51  Gaze point right X (MCSnorm)         5502 non-null   object
#  52  Gaze point right Y (MCSnorm)         5502 non-null   object
#  53  Presented Stimulus name              7248 non-null   object
#  54  Presented Media name                 7248 non-null   object
#  55  Presented Media width                7248 non-null   float64
#  56  Presented Media height               7248 non-null   float64
#  57  Presented Media position X (DACSpx)  7248 non-null   float64
#  58  Presented Media position Y (DACSpx)  7248 non-null   float64
#  59  Original Media width                 7248 non-null   float64
#  60  Original Media height                7248 non-null   float64
#  61  Eye movement type                    7268 non-null   object
#  62  Gaze event duration                  7268 non-null   float64
#  63  Eye movement type index              7268 non-null   float64
#  64  Fixation point X                     4216 non-null   float64
#  65  Fixation point Y                     4216 non-null   float64
#  66  Fixation point X (MCSnorm)           4009 non-null   object
#  67  Fixation point Y (MCSnorm)           4009 non-null   object
#  68  Mouse position X                     348 non-null    float64
#  69  Mouse position Y                     348 non-null    float64
# dtypes: float64(19), int64(5), object(46)
# memory usage: 3.9+ MB

# %%
par12_t0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7228 entries, 920 to 8147
# Data columns (total 70 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Recording timestamp                  7228 non-null   int64
#  1   Computer timestamp                   7228 non-null   int64
#  2   Sensor                               7225 non-null   object
#  3   Project name                         7228 non-null   object
#  4   Export date                          7228 non-null   object
#  5   Participant name                     7228 non-null   object
#  6   Recording name                       7228 non-null   object
#  7   Recording date                       7228 non-null   object
#  8   Recording date UTC                   7228 non-null   object
#  9   Recording start time                 7228 non-null   object
#  10  Recording start time UTC             7228 non-null   object
#  11  Recording duration                   7228 non-null   int64
#  12  Timeline name                        7228 non-null   object
#  13  Recording Fixation filter name       7228 non-null   object
#  14  Recording software version           7228 non-null   object
#  15  Recording resolution height          7228 non-null   int64
#  16  Recording resolution width           7228 non-null   int64
#  17  Recording monitor latency            7228 non-null   object
#  18  Eyetracker timestamp                 7206 non-null   float64
#  19  Event                                3 non-null      object
#  20  Event value                          2 non-null      object
#  21  Gaze point X                         5560 non-null   float64
#  22  Gaze point Y                         5560 non-null   float64
#  23  Gaze point left X                    4797 non-null   float64
#  24  Gaze point left Y                    4797 non-null   float64
#  25  Gaze point right X                   4803 non-null   float64
#  26  Gaze point right Y                   4803 non-null   float64
#  27  Gaze direction left X                4797 non-null   object
#  28  Gaze direction left Y                4797 non-null   object
#  29  Gaze direction left Z                4797 non-null   object
#  30  Gaze direction right X               4803 non-null   object
#  31  Gaze direction right Y               4803 non-null   object
#  32  Gaze direction right Z               4803 non-null   object
#  33  Pupil diameter left                  449 non-null    object
#  34  Pupil diameter right                 717 non-null    object
#  35  Validity left                        7206 non-null   object
#  36  Validity right                       7206 non-null   object
#  37  Eye position left X (DACSmm)         4797 non-null   object
#  38  Eye position left Y (DACSmm)         4797 non-null   object
#  39  Eye position left Z (DACSmm)         4797 non-null   object
#  40  Eye position right X (DACSmm)        4803 non-null   object
#  41  Eye position right Y (DACSmm)        4803 non-null   object
#  42  Eye position right Z (DACSmm)        4803 non-null   object
#  43  Gaze point left X (DACSmm)           4797 non-null   object
#  44  Gaze point left Y (DACSmm)           4797 non-null   object
#  45  Gaze point right X (DACSmm)          4803 non-null   object
#  46  Gaze point right Y (DACSmm)          4803 non-null   object
#  47  Gaze point X (MCSnorm)               5351 non-null   object
#  48  Gaze point Y (MCSnorm)               5351 non-null   object
#  49  Gaze point left X (MCSnorm)          4563 non-null   object
#  50  Gaze point left Y (MCSnorm)          4563 non-null   object
#  51  Gaze point right X (MCSnorm)         4729 non-null   object
#  52  Gaze point right Y (MCSnorm)         4729 non-null   object
#  53  Presented Stimulus name              7221 non-null   object
#  54  Presented Media name                 7221 non-null   object
#  55  Presented Media width                7221 non-null   float64
#  56  Presented Media height               7221 non-null   float64
#  57  Presented Media position X (DACSpx)  7221 non-null   float64
#  58  Presented Media position Y (DACSpx)  7221 non-null   float64
#  59  Original Media width                 7221 non-null   float64
#  60  Original Media height                7221 non-null   float64
#  61  Eye movement type                    7228 non-null   object
#  62  Gaze event duration                  7228 non-null   float64
#  63  Eye movement type index              7228 non-null   float64
#  64  Fixation point X                     2608 non-null   float64
#  65  Fixation point Y                     2608 non-null   float64
#  66  Fixation point X (MCSnorm)           2591 non-null   object
#  67  Fixation point Y (MCSnorm)           2591 non-null   object
#  68  Mouse position X                     19 non-null     float64
#  69  Mouse position Y                     19 non-null     float64
# dtypes: float64(19), int64(5), object(46)
# memory usage: 3.9+ MB

# %%
par1_t0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7466 entries, 3082 to 10547
# Data columns (total 70 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Recording timestamp                  7466 non-null   int64
#  1   Computer timestamp                   7466 non-null   int64
#  2   Sensor                               7462 non-null   object
#  3   Project name                         7466 non-null   object
#  4   Export date                          7466 non-null   object
#  5   Participant name                     7466 non-null   object
#  6   Recording name                       7466 non-null   object
#  7   Recording date                       7466 non-null   object
#  8   Recording date UTC                   7466 non-null   object
#  9   Recording start time                 7466 non-null   object
#  10  Recording start time UTC             7466 non-null   object
#  11  Recording duration                   7466 non-null   int64
#  12  Timeline name                        7466 non-null   object
#  13  Recording Fixation filter name       7466 non-null   object
#  14  Recording software version           7466 non-null   object
#  15  Recording resolution height          7466 non-null   int64
#  16  Recording resolution width           7466 non-null   int64
#  17  Recording monitor latency            7466 non-null   object
#  18  Eyetracker timestamp                 7201 non-null   float64
#  19  Event                                4 non-null      object
#  20  Event value                          3 non-null      object
#  21  Gaze point X                         6819 non-null   float64
#  22  Gaze point Y                         6819 non-null   float64
#  23  Gaze point left X                    6618 non-null   float64
#  24  Gaze point left Y                    6618 non-null   float64
#  25  Gaze point right X                   6472 non-null   float64
#  26  Gaze point right Y                   6472 non-null   float64
#  27  Gaze direction left X                6618 non-null   object
#  28  Gaze direction left Y                6618 non-null   object
#  29  Gaze direction left Z                6618 non-null   object
#  30  Gaze direction right X               6472 non-null   object
#  31  Gaze direction right Y               6472 non-null   object
#  32  Gaze direction right Z               6472 non-null   object
#  33  Pupil diameter left                  2254 non-null   object
#  34  Pupil diameter right                 2197 non-null   object
#  35  Validity left                        7201 non-null   object
#  36  Validity right                       7201 non-null   object
#  37  Eye position left X (DACSmm)         6618 non-null   object
#  38  Eye position left Y (DACSmm)         6618 non-null   object
#  39  Eye position left Z (DACSmm)         6618 non-null   object
#  40  Eye position right X (DACSmm)        6472 non-null   object
#  41  Eye position right Y (DACSmm)        6472 non-null   object
#  42  Eye position right Z (DACSmm)        6472 non-null   object
#  43  Gaze point left X (DACSmm)           6618 non-null   object
#  44  Gaze point left Y (DACSmm)           6618 non-null   object
#  45  Gaze point right X (DACSmm)          6472 non-null   object
#  46  Gaze point right Y (DACSmm)          6472 non-null   object
#  47  Gaze point X (MCSnorm)               5048 non-null   object
#  48  Gaze point Y (MCSnorm)               5048 non-null   object
#  49  Gaze point left X (MCSnorm)          4816 non-null   object
#  50  Gaze point left Y (MCSnorm)          4816 non-null   object
#  51  Gaze point right X (MCSnorm)         4817 non-null   object
#  52  Gaze point right Y (MCSnorm)         4817 non-null   object
#  53  Presented Stimulus name              7462 non-null   object
#  54  Presented Media name                 7462 non-null   object
#  55  Presented Media width                7462 non-null   float64
#  56  Presented Media height               7462 non-null   float64
#  57  Presented Media position X (DACSpx)  7462 non-null   float64
#  58  Presented Media position Y (DACSpx)  7462 non-null   float64
#  59  Original Media width                 7462 non-null   float64
#  60  Original Media height                7462 non-null   float64
#  61  Eye movement type                    7465 non-null   object
#  62  Gaze event duration                  7465 non-null   float64
#  63  Eye movement type index              7465 non-null   float64
#  64  Fixation point X                     3959 non-null   float64
#  65  Fixation point Y                     3959 non-null   float64
#  66  Fixation point X (MCSnorm)           2518 non-null   object
#  67  Fixation point Y (MCSnorm)           2518 non-null   object
#  68  Mouse position X                     261 non-null    float64
#  69  Mouse position Y                     261 non-null    float64
# dtypes: float64(19), int64(5), object(46)
# memory usage: 4.0+ MB

# %%
dfs = [par1_t0, par12_t0, par1_t0]
demo_data = pd.concat(dfs)
demo_data.head()
# Out:
#       Recording timestamp  Computer timestamp       Sensor  \
# 3082             23419315           512092386          NaN
# 3083             23419315           512092386          NaN
# 3084             23426120           512099191  Eye Tracker
# 3085             23434449           512107520  Eye Tracker
# 3086             23442782           512115853  Eye Tracker
#
#                Project name Export date Participant name Recording name  \
# 3082  Test group experiment  24.09.2020  Participant0001     Recording1
# 3083  Test group experiment  24.09.2020  Participant0001     Recording1
# 3084  Test group experiment  24.09.2020  Participant0001     Recording1
# 3085  Test group experiment  24.09.2020  Participant0001     Recording1
# 3086  Test group experiment  24.09.2020  Participant0001     Recording1
#
#      Recording date Recording date UTC Recording start time  \
# 3082     24.09.2020         24.09.2020         15:17:34.920
# 3083     24.09.2020         24.09.2020         15:17:34.920
# 3084     24.09.2020         24.09.2020         15:17:34.920
# 3085     24.09.2020         24.09.2020         15:17:34.920
# 3086     24.09.2020         24.09.2020         15:17:34.920
#
#      Recording start time UTC  Recording duration Timeline name  \
# 3082             13:17:34.920               83579     Timeline1
# 3083             13:17:34.920               83579     Timeline1
# 3084             13:17:34.920               83579     Timeline1
# 3085             13:17:34.920               83579     Timeline1
# 3086             13:17:34.920               83579     Timeline1
#
#      Recording Fixation filter name Recording software version  \
# 3082          Tobii I-VT (Fixation)                1.145.28180
# 3083          Tobii I-VT (Fixation)                1.145.28180
# 3084          Tobii I-VT (Fixation)                1.145.28180
# 3085          Tobii I-VT (Fixation)                1.145.28180
# 3086          Tobii I-VT (Fixation)                1.145.28180
#
#       Recording resolution height  Recording resolution width  \
# 3082                         1080                        1920
# 3083                         1080                        1920
# 3084                         1080                        1920
# 3085                         1080                        1920
# 3086                         1080                        1920
#
#      Recording monitor latency  Eyetracker timestamp  \
# 3082                     10,00                   NaN
# 3083                     10,00                   NaN
# 3084                     10,00           509880650.0
# 3085                     10,00           509888979.0
# 3086                     10,00           509897311.0
#
#                             Event   Event value  Gaze point X  Gaze point Y  \
# 3082  Eye tracker Calibration end           NaN           NaN           NaN
# 3083           ImageStimulusStart  e-tranboard0           NaN           NaN
# 3084                          NaN           NaN         962.0         346.0
# 3085                          NaN           NaN         962.0         350.0
# 3086                          NaN           NaN         962.0         346.0
#
#       Gaze point left X  Gaze point left Y  Gaze point right X  \
# 3082                NaN                NaN                 NaN
# 3083                NaN                NaN                 NaN
# 3084              943.0              290.0               980.0
# 3085              912.0              292.0              1012.0
# 3086              912.0              292.0              1012.0
#
#       Gaze point right Y Gaze direction left X Gaze direction left Y  \
# 3082                 NaN                   NaN                   NaN
# 3083                 NaN                   NaN                   NaN
# 3084               402.0               0,07366               0,00290
# 3085               409.0               0,06367               0,00355
# 3086               400.0               0,06370               0,00355
#
#      Gaze direction left Z Gaze direction right X Gaze direction right Y  \
# 3082                   NaN                    NaN                    NaN
# 3083                   NaN                    NaN                    NaN
# 3084              -0,99728                0,00460                0,04058
# 3085              -0,99796                0,01509                0,04295
# 3086              -0,99796                0,01510                0,04013
#
#      Gaze direction right Z Pupil diameter left Pupil diameter right  \
# 3082                    NaN                 NaN                  NaN
# 3083                    NaN                 NaN                  NaN
# 3084               -0,99917                 NaN                  NaN
# 3085               -0,99896                 NaN                  NaN
# 3086               -0,99908                3,21                 3,14
#
#      Validity left Validity right Eye position left X (DACSmm)  \
# 3082           NaN            NaN                          NaN
# 3083           NaN            NaN                          NaN
# 3084         Valid          Valid                        197,2
# 3085         Valid          Valid                        197,2
# 3086         Valid          Valid                        197,2
#
#      Eye position left Y (DACSmm) Eye position left Z (DACSmm)  \
# 3082                          NaN                          NaN
# 3083                          NaN                          NaN
# 3084                         76,9                        829,0
# 3085                         76,9                        829,0
# 3086                         76,9                        829,0
#
#      Eye position right X (DACSmm) Eye position right Y (DACSmm)  \
# 3082                           NaN                           NaN
# 3083                           NaN                           NaN
# 3084                         264,8                          76,0
# 3085                         264,8                          75,8
# 3086                         264,8                          75,7
#
#      Eye position right Z (DACSmm) Gaze point left X (DACSmm)  \
# 3082                           NaN                        NaN
# 3083                           NaN                        NaN
# 3084                         837,4                      258,5
# 3085                         837,8                      250,1
# 3086                         838,2                      250,1
#
#      Gaze point left Y (DACSmm) Gaze point right X (DACSmm)  \
# 3082                        NaN                         NaN
# 3083                        NaN                         NaN
# 3084                       79,4                       268,6
# 3085                       79,9                       277,4
# 3086                       79,9                       277,4
#
#      Gaze point right Y (DACSmm) Gaze point X (MCSnorm)  \
# 3082                         NaN                    NaN
# 3083                         NaN                    NaN
# 3084                       110,0                 0,5011
# 3085                       111,9                 0,5016
# 3086                       109,4                 0,5016
#
#      Gaze point Y (MCSnorm) Gaze point left X (MCSnorm)  \
# 3082                    NaN                         NaN
# 3083                    NaN                         NaN
# 3084                 0,3203                      0,4886
# 3085                 0,3244                      0,4682
# 3086                 0,3202                      0,4682
#
#      Gaze point left Y (MCSnorm) Gaze point right X (MCSnorm)  \
# 3082                         NaN                          NaN
# 3083                         NaN                          NaN
# 3084                      0,2685                       0,5135
# 3085                      0,2703                       0,5350
# 3086                      0,2703                       0,5350
#
#      Gaze point right Y (MCSnorm) Presented Stimulus name  \
# 3082                          NaN                     NaN
# 3083                          NaN                     NaN
# 3084                       0,3721            e-tranboard0
# 3085                       0,3785            e-tranboard0
# 3086                       0,3701            e-tranboard0
#
#      Presented Media name  Presented Media width  Presented Media height  \
# 3082                  NaN                    NaN                     NaN
# 3083                  NaN                    NaN                     NaN
# 3084      e-tranboard.png                 1493.0                  1080.0
# 3085      e-tranboard.png                 1493.0                  1080.0
# 3086      e-tranboard.png                 1493.0                  1080.0
#
#       Presented Media position X (DACSpx)  \
# 3082                                  NaN
# 3083                                  NaN
# 3084                                214.0
# 3085                                214.0
# 3086                                214.0
#
#       Presented Media position Y (DACSpx)  Original Media width  \
# 3082                                  NaN                   NaN
# 3083                                  NaN                   NaN
# 3084                                  0.0                 897.0
# 3085                                  0.0                 897.0
# 3086                                  0.0                 897.0
#
#       Original Media height Eye movement type  Gaze event duration  \
# 3082                    NaN          Fixation                117.0
# 3083                    NaN          Fixation                117.0
# 3084                  649.0          Fixation                117.0
# 3085                  649.0          Fixation                117.0
# 3086                  649.0          Fixation                117.0
#
#       Eye movement type index  Fixation point X  Fixation point Y  \
# 3082                     64.0             971.0             341.0
# 3083                     64.0             971.0             341.0
# 3084                     64.0             971.0             341.0
# 3085                     64.0             971.0             341.0
# 3086                     64.0             971.0             341.0
#
#      Fixation point X (MCSnorm) Fixation point Y (MCSnorm)  Mouse position X  \
# 3082                     0,5073                     0,3160               NaN
# 3083                     0,5073                     0,3160               NaN
# 3084                     0,5073                     0,3160               NaN
# 3085                     0,5073                     0,3160               NaN
# 3086                     0,5073                     0,3160               NaN
#
#       Mouse position Y
# 3082               NaN
# 3083               NaN
# 3084               NaN
# 3085               NaN
# 3086               NaN

# %%
#Computer timestamp: The timestamps that uniquely identify a recording and which can later be used to analyse data, hence we are retaining this column.
#Recorded timestamp: Gives similar data as the computer timestamp column, hence we will be deleting this column.
#Sensor type
demo_data['Sensor'].value_counts()
# Out:
# Eye Tracker    21608
# Mouse            541
# Name: Sensor, dtype: int64

# %%
#Project name
demo_data['Project name'].value_counts()
# Out:
# Test group experiment    14932
# Participant0012           7228
# Name: Project name, dtype: int64

# %%
#'Export date', 'Recording date', 'Recording date UTC', 'Recording start time', 'Recording start time UTC', 'Recording duration', 'Timeline name', 'Recording Fixation filter name', 'Recording software version' will be dropped as the data does not affect the target in any way.
demo_data['Recording resolution height'].value_counts()
# Out:
# 1080    22160
# Name: Recording resolution height, dtype: int64

# %%
demo_data['Recording resolution width'].value_counts()
# Out:
# 1920    22160
# Name: Recording resolution width, dtype: int64

# %%
demo_data['Recording monitor latency'].value_counts()
# Out:
# 10,00    22160
# Name: Recording monitor latency, dtype: int64

# %%
#Event
demo_data['Event'].value_counts()
# Out:
# Eye tracker Calibration end    3
# ImageStimulusStart             3
# ImageStimulusEnd               3
# MouseEvent                     2
# Name: Event, dtype: int64

# %%
#Presented Stimulus name
demo_data['Presented Stimulus name'].value_counts()
# Out:
# e-tranboard0            14924
# thumbnail_grossTrial     7221
# Name: Presented Stimulus name, dtype: int64

# %%
#Eye movement type
demo_data['Eye movement type'].value_counts()
# Out:
# Fixation        10526
# Unclassified     4817
# Saccade          4464
# EyesNotFound     2351
# Name: Eye movement type, dtype: int64

# %%
#Gaze event duration
sns.distplot(demo_data['Gaze event duration'])
# Out:
# C:\Users\sm22181\AppData\Local\Temp\ipykernel_13004\148565987.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(demo_data['Gaze event duration'])
# <Axes: xlabel='Gaze event duration', ylabel='Density'>

# %%
#Gaze point X and Gaze point Y
demo_data['Gaze point X'], demo_data['Gaze point Y']
# Out:
# (3082       NaN
#  3083       NaN
#  3084     962.0
#  3085     962.0
#  3086     962.0
#           ...
#  10543    462.0
#  10544    482.0
#  10545    480.0
#  10546    529.0
#  10547      NaN
#  Name: Gaze point X, Length: 22160, dtype: float64,
#  3082       NaN
#  3083       NaN
#  3084     346.0
#  3085     350.0
#  3086     346.0
#           ...
#  10543    201.0
#  10544    218.0
#  10545    213.0
#  10546    217.0
#  10547      NaN
#  Name: Gaze point Y, Length: 22160, dtype: float64)
